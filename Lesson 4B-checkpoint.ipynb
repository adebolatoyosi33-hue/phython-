# %%
#Question 1 Student score Tracker

score=60
score+=15
score-=5
score*=2

print(score)
# Out:
# 140

# %%
#Questin 2 digital wallet Stimulator

balance=25000
balance+=8500
balance-=4200
balance/=3

print(balance)
print(type(balance))
# Out:
# 9766.666666666666
# <class 'float'>

# %%
#Question 3 Inventory Management System

stock=150
stock-=28
stock+=75
stock//=12

print(stock)
# Out:
# 16
