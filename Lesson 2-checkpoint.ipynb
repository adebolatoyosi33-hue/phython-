# %%
#Creating Personal details
full_name = "Toyosi Adebola"
current_age = "28"
country = "Nigeria"

print("Name :",full_name)
print("Age :",current_age)
print("Country :",country)
# Out:
# Name : Toyosi Adebola
# Age : 28
# Country : Nigeria

# %%
#Salary Calculation
basic_salary = 180000
bonus = 35000
total_salary = basic_salary  + bonus
print("Basic Salary :",basic_salary)
print("Bonus :", bonus)
print("Total Salary :", total_salary)
# Out:
# Basic Salary : 180000
# Bonus : 35000
# Total Salary : 215000

# %%
#User input
name = input("Enter you name:")
favourite_language = input("Enter your favourite programming language :")
print("Hello",name )
print("Your favourite programming langauage is :", favourite_language)
# Out:
# Enter you name: Adebola Toyosi
# Enter your favourite programming language : Python
# Hello Adebola Toyosi
# Your favourite programming langauage is : Python

# %%
#Working with Data type
user_id = 234
score = 99.9
name = "Adebola Toyosi"
is_pass = True

#values and data
print(id,type(user_id))
print(score, type(score))
print(name, type(name))
print(is_pass, type(is_pass))
# Out:
# 234 <class 'int'>
# 99.9 <class 'float'>
# Adebola Toyosi <class 'str'>
# True <class 'bool'>

# %%
#changing of data type
user_id = 234
print(user_id,type(user_id))

#change data type
user_id_str = str(user_id)
print(user_id_str, type(user_id_str))
# Out:
# 234 <class 'int'>
# 234 <class 'str'>

# %%
#Student Information card
full_name = input("Enter your full name :")
age = input("Enter your age :")
course = input("Enter your course :")
country = input("Enter your country :")

print("Name :", full_name)
print("Age :", age)
print("Course :", course)
print("Country :", country)

print("Name :", type(full_name))
print("Age :", type(age))
print("Course :", type(course))
print("Country :", type(country))

#convertion of age to int
age_str = int(age)
print("Successfully converted string to int for age :", type(age_str))
# Out:
# Enter your full name : Adebola Toyosi
# Enter your age : 28
# Enter your course : Python
# Enter your country : Nigeria
# Name : Adebola Toyosi
# Age : 28
# Course : Python
# Country : Nigeria
# Name : <class 'str'>
# Age : <class 'str'>
# Course : <class 'str'>
# Country : <class 'str'>
# Successfully converted string to int for age : <class 'int'>
