# %%
print("Hello, World!")
print("My name is Toyosi Adebola")
print("I am learning Python.")
print("Programming is exciting!")
# Out:
# Hello, World!
# My name is Toyosi Adebola
# I am learning Python.
# Programming is exciting!

# %%
print("My favorite food is Rice.")
print("My favorite movie is abattoir.")
print("My favorite sport is football.")
print("My favorite color is black.")
# Out:
# My favorite food is Rice.
# My favorite movie is abattoir.
# My favorite sport is football.
# My favorite color is black.

# %%
print(15+5)
print(30-12)
print(9*8)
print(72/9)
print(18%5)
print(10//3)
print(5^2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 7

# %%
#Display programming language
print("Python")
#Sector I am currently learning
print("Programming")
#Current lesson I'm undergoing
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %%
print("My name is Toyosi Adebola")
print("My dream career is Pharmacy")
print("My country is Nigeria")
# Out:
# My name is Toyosi Adebola
# My dream career is Pharmacy
# My country is Nigeria

# %%
print("My name is Toyosi Adebola")
#My dream career
print("My dream career is Pharmacy")
#My country
print("My country is Nigeria")
#Arithmetic solution
print(25+75)
print(40//6)
print(8^2)
# Out:
# My name is Toyosi Adebola
# My dream career is Pharmacy
# My country is Nigeria
# 100
# 6
# 10
