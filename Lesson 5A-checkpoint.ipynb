# %%
#Lesson 5A Hand on Exercise

#Ex.1 Customer Registration System
customer_name= "Ayoola Michael"
email_address= "ayoolamichael001@gmail.com"
phone_number= "07065385978"
country= "Nigeria"
occupation= "scientist"

print("Name:", customer_name)
print("Email:", email_address)
print("Phone:", phone_number)
print("Country:", country)
print("Occupation:", occupation)
# Out:
# Name: Ayoola Michael
# Email: ayoolamichael001@gmail.com
# Phone: 07065385978
# Country: Nigeria
# Occupation: scientist

# %%
#Ex.2 Hospital Patient Record
patient_name= "Bakare Tobi"
doctors_name= "Dr Leo"
patient_diagnosis= "Malaria"
blood_group= "A+"
hospital= "Ekiti state university teaching hospital"

print("PATIENT RECORD")

print("Patient:", patient_name)
print("Doctor:", doctors_name)
print("Diagnosis:", patient_diagnosis)
print("Blood Group:", blood_group)
print("Hospital:", hospital)

report="""Dr Leo in Ekiti state university teaching hospital,
Diagnosed, 
Bakare Tobi with blood group A+ of Malaria."""
print(report)
# Out:
# PATIENT RECORD
# Patient: Bakare Tobi
# Doctor: Dr Leo
# Diagnosis: Malaria
# Blood Group: A+
# Hospital: Ekiti state university teaching hospital
# Dr Leo in Ekiti state university teaching hospital,
# Diagnosed,
# Bakare Tobi with blood group A+ of Malaria.

# %%
#Ex.3 AI Prompt Builder

prompt="""You are an AI Assistant,
Analyze customer feedback,identify common complaints,Provide recommendations,and 
Generate a summary report."""
print(prompt)
# Out:
# You are an AI Assistant,
# Analyze customer feedback,identify common complaints,Provide recommendations,and
# Generate a summary report.
