# %%
#Question 1 secure login system

username_correct=True 
password_correct=True
account_locked=False

if username_correct and password_correct and account_locked:

     print("Access Granted")
else:
     print("Access Denied")
# Out:
# Access Denied

# %%
#Question 2 university scholarship eligibility

score=85
participated=True
low_income=False

if score>=80 and (participated or low_income):
    print("Congratulation!")
    print("Scholarship Approved.")
# Out:
# Congratulation!
# Scholarship Approved.

# %%
#Question 3 Smart Server Health Monitor

cpu_usage=75
memory_usage=92
disk_usage=60

if cpu_usage>90 and memory_usage>90 and disk_usage>95:
    print("Critical Alert")
else:
    print("System Healthy")
# Out:
# System Healthy

# %%
#challenge

logged_in=True
item_available=True
funds_available= True
account_suspended=False

if logged_in and item_available and funds_available and account_suspended:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Failed
