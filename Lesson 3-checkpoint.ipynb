# %%
#Question 1 Employee payroll & bonue eligibility

#Calculate the employee total salary
basic_salary=180000
bonus=45000
total_salary=basic_salary+bonus

print("Employee total salary :", total_salary)

#Premium package
premium_package=220000

is_eligible=total_salary >= premium_package
print("Employee premium benefit :", is_eligible)
# Out:
# Employee total salary : 225000
# Employee premium benefit : True

# %%
#Question 2 Student Performance Evaluation

#list of assessment scores
python_score=72
sql_score=65
excel_score=80
power_bi_score=75

assessments_score=4

#calculate total score
total_score=292

#calculate the avarage score
average_score=total_score/assessments_scores

print("Average Score:" , average_score)

#Determine whether the students passed.
passed=average_score>=70

print("Passed:" , passed)
# Out:
# Average Score: 73.0
# Passed: True

# %%
#Question 3 Inventory Management System

initial_stocks=250
sold=85

#calculate remaining stocks
remaining_stocks=initial_stocks-sold

print("Remaining Stock:", remaining_stocks)

#Determine whether the warehouse should reorder inventory

reorder=remaining_stocks<200
print("Reorder Needed:" , reorder)
# Out:
# Remaining Stock: 165
# Reorder Needed: True

# %%
#Question 4 Banking Withdrawal Checker

account_balance=520000
customer_withdraw=150000

#calculate balance after withdrawal
remaining_balance=account_balance-customer_withdraw

print("Remaining Balance:" , remaining_balance)

#Determine whether the withdrawal can be approved.
withdrawal_approved=account_balance>=customer_withdraw

print("Withdrawal Approved:" , withdrawal_approved)
# Out:
# Remaining Balance: 370000
# Withdrawal Approved: True
